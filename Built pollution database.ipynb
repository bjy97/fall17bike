# %%
import os
from sqlalchemy import *
from sqlalchemy.pool import NullPool
from flask import Flask, request, render_template, g, redirect, Response, session, url_for
from flask_wtf import FlaskForm
from wtforms import DateField, SelectField
import pandas as pd 
import numpy as np

# %%
DATABASEURI = "postgresql://postgres:None@35.196.207.52"

engine = create_engine(DATABASEURI)
conn = engine.connect()

# %%
qry = conn.execute('select * from phase;')
count = 0
for i in qry:
    count+=1
print(count)
# Out:
# 504

# %%
df = pd.read_csv('phase1_dataset_all_parameters_20170907.csv')

# %%
use_db = pd.read_csv('phase1_when_biking.csv')

# %%
df = pd.read_csv('gps_merged0727.csv')

# %%
df['datetime'].iloc[0]

# %%
use_db
# Out:
#        Unnamed: 0   subject             datetime  pm.clean.DL  \
# 0             628  BIKE0001  2015-06-17 08:28:00     2.666667
# 1             629  BIKE0001  2015-06-17 08:29:00    10.666667
# 2             630  BIKE0001  2015-06-17 08:30:00     3.000000
# 3             631  BIKE0001  2015-06-17 08:31:00     4.000000
# 4             632  BIKE0001  2015-06-17 08:32:00     6.666667
# 5             633  BIKE0001  2015-06-17 08:33:00    15.666667
# 6             634  BIKE0001  2015-06-17 08:34:00     6.333333
# 7             635  BIKE0001  2015-06-17 08:35:00     4.333333
# 8             636  BIKE0001  2015-06-17 08:36:00     7.000000
# 9             637  BIKE0001  2015-06-17 08:37:00     8.000000
# 10            638  BIKE0001  2015-06-17 08:38:00     8.666667
# 11            639  BIKE0001  2015-06-17 08:39:00     8.000000
# 12            640  BIKE0001  2015-06-17 08:40:00     8.666667
# 13            641  BIKE0001  2015-06-17 08:41:00     4.333333
# ...

# %%
longitude = df['longitude'].iloc[1]
latitude = df['latitude'].iloc[1]
clean = df['pm.clean'].iloc[1]
time = df['datetime'].iloc[1]

# %%
a = df['subject'].iloc[1]
a = foo(a)

# %%
time = foo(time)

# %%
query = 'INSERT INTO pollution VALUES (' + a +','+time + ','+ str(longitude) +', ' + str(latitude) +', '+ str(clean)+ ');'

# %%
query1 = 'INSERT INTO pollution VALUES (' + a +','+time + ','+ str(longitude) +', ' + str(latitude)+ ');'

# %%
np.isnan(clean)

# %%
query1

# %%
conn.execute(query1)

# %%
def foo(s1):
    return("'{}'".format(s1))

# %%
def create_query(line):
    
    
    query = "insert into test "
    bid = line[1]
    b_date = line[2]
    values = "values ("
    values+= foo(bid) + ', '
    values+= foo(b_date) + ', '
    
    sub = "(subject, datetime, "
    
    if line[3]!='':
        values+= line[3] + ', '
        sub+='pm, '
    if line[4]!='':
        values+= line[4] + ', '
        sub+='bc, '
    if line[5]!='':
        values+= line[5] + ', '
        sub+= 'mv, '
    if line[6]!='':
        values+= line[6] + ', '
        sub+='bcdose, '
    if line[7]!='':
        values+= line[7] + ', '
        sub+='pmdose, '
    
    sub+='biking) '
    
    values += line[-1]
    query += sub
    query += values + ');'
        
    return query
            #Check if value is null for each of the five parameters

# %%
datafile = 'phase1_when_biking.csv'
header = True
count = 0
with open(datafile,'r') as f:
    for line in f:
        line = line.strip().split(',')
        print(line)
        if header:
            header = False
            continue
        try:
            query = create_query(line)
            try:
                conn.execute(query)
            except:
                continue
            count+=1
            #if count%100 == 0:
                #conn.commit()
            
        except:
            continue
print(count)
# Out:
# ['', 'subject', 'datetime', 'pm.clean.DL', 'pm.clean.corrected.by.bcpm.ratio', 'mv.clean.by.hr.act', 'bc.dose', 'pm.dose', 'biking']
# ['628', 'BIKE0001', '2015-06-17 08:28:00', '2.6666666666666696', '2.6666666666666696', '66.0900000000002', '46.32909000000011', '176.240000000001', '-1']
# ['629', 'BIKE0001', '2015-06-17 08:29:00', '10.6666666666667', '10.6666666666667', '74.27', '192.247895', '792.213333333336', '-1']
# ['630', 'BIKE0001', '2015-06-17 08:30:00', '3.0', '', '73.37', '454.01356', '', '-1']
# ['631', 'BIKE0001', '2015-06-17 08:31:00', '4.0', '', '71.0100000000002', '469.447110000001', '', '-1']
# ['632', 'BIKE0001', '2015-06-17 08:32:00', '6.66666666666667', '6.66666666666667', '64.3899999999998', '282.67209999999903', '429.266666666666', '-1']
# ['633', 'BIKE0001', '2015-06-17 08:33:00', '15.666666666666698', '15.666666666666698', '68.4999999999998', '363.76924999999903', '1073.16666666667', '-1']
# ...

# %%
create_query(['628', 'BIKE0001', '2015-06-17 08:28:00', '2.6666666666666696', '2.6666666666666696', '66.0900000000002', '46.32909000000011', '176.240000000001', '-1'])
# Out:
# "insert into phase (subject, datetime, pm, bc, mv, bcdose, pmdose, biking) values ('BIKE0001', '2015-06-17 08:28:00', 2.6666666666666696, 2.6666666666666696, 66.0900000000002, 46.32909000000011, 176.240000000001, -1);"

# %%
create_query(['630', 'BIKE0001', '2015-06-17 08:30:00', '3.0', '', '73.37', '454.01356', '', '-1'])
# Out:
# "insert into phase (subject, datetime, pm, mv, bcdose, biking) values ('BIKE0001', '2015-06-17 08:30:00', 3.0, 73.37, 454.01356, -1);"

# %%
if line[3]=='':
                pm = False
            if line[4]=='':
                bc = False
            if line[5]=='':
                mv = False
            if line[6]=='':
                mvbc = False
            if line[7]=='':
                mvpm = False
            
            biking = int(line[-1])

# %%
header = True
count=0
with open(datafile,'r') as f:
    for line in f:
        line = line.strip().split(',')
        if header:
            header = False
            continue
        #Set up data and ignore any line where it fails
        try:
            u_id = int(line[0])
            c_date =datetime.datetime.strptime(line[1][0:10],"%M/%d/%Y").date()
            agency = line[2]
            borough = line[3]
            latitude = float(line[4])
            longitude = float(line[5])
            query = 'INSERT INTO INCIDENTS (unique_key, Date,Agency,Borough,Latitude,Longitude) VALUES ('
            query += str(u_id) + ',"'
            query += str(c_date) + '","'
            query += agency + '","'
            query += borough + '",'
            query += str(latitude) + ','
            query += str(longitude) + ');'        
            try:
                cursor.execute(query)
            except:
                continue
            count+=1
            if count%100 == 0:
                db.commit()
        except:
            continue

print(count) 
db.commit()

# %%
a = 2
string = 'how do you like'+str(a)

# %%
string

# %%
string = 'BIKE0001'
a = 2
result = foo(string)+str(a)
print(result)

# %%
(bikeid, datetime, longitude, latitude)
